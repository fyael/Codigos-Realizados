# %%
import os
import re
import requests
import wget
from glob import glob
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from nltk.tokenize import TweetTokenizer
import random

from nltk.tokenize import word_tokenize

import html5lib
import nltk

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk import FreqDist

# %%
headers = {
    "User-Agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.93 Safari/537.36'}
response = requests.get("https://www.gutenberg.org/browse/languages/es", headers=headers)

#pg = open('pagina.txt','wb').write(response.content)

# %% [markdown]
# ### Obtener los nombres desde la página

# %%
driver = webdriver.Firefox()

driver.get('https://es.wikisource.org/wiki/Categor%C3%ADa:Cuentos')

lista_titles = []
for i in range(7):

    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(1)

    #button = WebDriverWait(driver, 2).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "button[name='gs_btnPD gs_in_ib gs_btn_flat gs_btn_lrge gs_btn_lsu']"))).click()
    #button_close1 = driver.find_element(By.XPATH, '//div[@aria-label="Mostrar más"]').click()



    columns = driver.find_elements(By.CLASS_NAME, "mw-category-columns")
    for ul in columns:

        #print(ul.text)
        #print(tit.text)
        titles = ul.find_elements(By.TAG_NAME, 'ul')
        for titl in titles:
            #print(titl.text)
            lista_titles.append(titl.text)
        #print(titles.text)



    try:
        button = driver.find_element(By.XPATH, '//a[text()="página siguiente"]').click()
    except NoSuchElementException:
        break

driver.close()
print(lista_titles)
# Out:
# KeyboardInterrupt

# %%
for i in lista_titles:
    print(i)
# Out:
# Portal:Cuento
# A Casta
# A la deriva
# A la plata
# A la sombra de un chaparro
# A la vera del brasero
# A María Josefa
# A muerte (Lugones)
# A París (Gagini)
# A quién debe darse crédito
# A solas con mi demonio
# Abuelita (Andersen)
# Accidentado paseo a Moka
# Accidente
# Acuarela 1
# Acuarela 2
# Acuérdate de Azerbaijan
# Acúsome padre
# Aguafuerte
# Aire
# Al alimón
# Al anochecer
# Al borde
# Al carbón
# Al colmenar con careta
# Al llegar
# Al rastro
# Al rescoldo
# Alerta (Lugones)
# Alféizar
# «Algo»
# Algo (Andersen, García Ramón tr.)
# Alma andaluza
# Almas errantes
# Almas honradas
# Almas prestadas. Heliodoro, el reloj, mi nuevo amigo
# Amapola
# Amor de niño
# Amor eterno
# Amor'è furbo
# Amparo
# Ana Isabel
# Ante el Cónsul
# Antonieta
# Apólogo
# Arenero
# Artillería
# Arturo Trailles
# Aurore y Aimée
# Avecilla
# Aventura sin igual de un tal Hans Pfaall
# Aventuras de Sherlock Holmes (Tomo I)
# Aventuras de un cardo
# Azul...
# Badía hermanos
# Bagajes
# ...

# %%
lista=[]
with open ('./titles_books.txt', 'r', encoding='utf-8') as file:
    f = file.readlines()
    for l in f:
        l = re.sub('\n','',l)
        lista.append(l)

print(lista)
print(len(lista))
# Out:
# ['A Casta', 'A la deriva', 'A la plata', 'A la sombra de un chaparro', 'A la vera del brasero', 'A María Josefa', 'A muerte (Lugones)', 'A París (Gagini)', 'A quién debe darse crédito', 'A solas con mi demonio', 'Abuelita (Andersen)', 'Accidentado paseo a Moka', 'Accidente', 'Acuarela 1', 'Acuarela 2', 'Acuérdate de Azerbaijan', 'Acúsome padre', 'Aguafuerte', 'Aire', 'Al alimón', 'Al anochecer', 'Al borde', 'Al carbón', 'Al colmenar con careta', 'Al llegar', 'Al rastro', 'Al rescoldo', 'Alerta (Lugones)', 'Alféizar', '«Algo»', 'Algo (Andersen, García Ramón tr.)', 'Alma andaluza', 'Almas errantes', 'Almas honradas', 'Almas prestadas. Heliodoro, el reloj, mi nuevo amigo', 'Amapola', 'Amor de niño', 'Amor eterno', "Amor'è furbo", 'Amparo', 'Ana Isabel', 'Ante el Cónsul', 'Antonieta', 'Apólogo', 'Arenero', 'Artillería', 'Arturo Trailles', 'Aurore y Aimée', 'Avecilla', 'Aventura sin igual de un tal Hans Pfaall', 'Aventuras de Sherlock Holmes (Tomo I)', 'Aventuras de un cardo', 'Azul...', 
# ...

# %%
list_titles = []

for title_i in lista:
    list_titles.append(f'<title>{title_i}</title>')

# %%
print(list_titles)
len(list_titles)
# Out:
# ['<title>A Casta</title>', '<title>A la deriva</title>', '<title>A la plata</title>', '<title>A la sombra de un chaparro</title>', '<title>A la vera del brasero</title>', '<title>A María Josefa</title>', '<title>A muerte (Lugones)</title>', '<title>A París (Gagini)</title>', '<title>A quién debe darse crédito</title>', '<title>A solas con mi demonio</title>', '<title>Abuelita (Andersen)</title>', '<title>Accidentado paseo a Moka</title>', '<title>Accidente</title>', '<title>Acuarela 1</title>', '<title>Acuarela 2</title>', '<title>Acuérdate de Azerbaijan</title>', '<title>Acúsome padre</title>', '<title>Aguafuerte</title>', '<title>Aire</title>', '<title>Al alimón</title>', '<title>Al anochecer</title>', '<title>Al borde</title>', '<title>Al carbón</title>', '<title>Al colmenar con careta</title>', '<title>Al llegar</title>', '<title>Al rastro</title>', '<title>Al rescoldo</title>', '<title>Alerta (Lugones)</title>', '<title>Alféizar</title>', '<title>«Algo»</title>', '<title>Algo (A
# ...

# %% [markdown]
# ### Guardar en lista TODOS los titulos del archivo

# %%
with open('./Todos_los_titulos.txt', 'r', encoding='utf-8') as titles_file:
    lista_titles_all = [line.strip() for line in titles_file.readlines()]

# %% [markdown]
# ### Extraer los libros del archivo

# %%
libros_no_estan=[]
lista_titles_all=[]

contador = 0
with open('C:/Users/Yael/Downloads/eswikisource-20240701-pages-articles-multistream.xml','r',encoding='utf-8') as books_file_:
    books_cont = books_file_.read()  


    
    for f_title in list_titles:
        current_title=0
        next_title=0
        
        start_line = 0
        end_line=0
        
        f_title = re.sub('"','&quot;', f_title)
        try:
            
            current_title=lista_titles_all.index(f_title)
            next_title = current_title+1
            
            #print('\n\n\n',lista_titles_all[current_title])
            #print(lista_titles_all[next_title])
            contador+=1
            
            start_line = books_cont.find(lista_titles_all[current_title])
            end_line = books_cont.find(lista_titles_all[next_title])
            
            #print(start_line, end_line, '\n\n\n')
            f_title = re.sub(r'<title>|</title>', '', f_title)
            f_title = re.sub(r'[\\/*?:"<>|]','-', f_title)
            
            
            with open('./Libros_Wiki/'+f_title+'.txt', 'w', encoding='utf-8') as write_book:
                write_book.write(books_cont[start_line:end_line])
            
        except:
            
            print('no esta', f_title)
print(contador)
# Out:
# 1292

# %%
no esta <title>La dama de "pique"</title>
no esta <title>"Sic transit..."</title>
no esta <title>"Ven, mi ama Zobeida quiere hablarte."</title>
1289
# Out:
# ['<title>MediaWiki:Monobook.js</title>',
#  '<title>MediaWiki:Currentevents</title>',
#  '<title>MediaWiki:Currentevents-url</title>',
#  '<title>MediaWiki:Disambiguationspage</title>',
#  '<title>MediaWiki:Disclaimerpage</title>',
#  '<title>MediaWiki:Disclaimers</title>',
#  '<title>MediaWiki:Newarticletext</title>',
#  '<title>MediaWiki:Protectlogtext</title>',
#  '<title>MediaWiki:Recentchangestext</title>',
#  '<title>MediaWiki:Showdiff</title>',
#  '<title>MediaWiki:Sitenotice</title>',
#  '<title>MediaWiki:Sitesubtitle</title>',
#  '<title>MediaWiki:Sitesupport-url</title>',
#  '<title>MediaWiki:Sitetitle</title>',
#  '<title>MediaWiki:Stubthreshold</title>',
#  '<title>MediaWiki:Tagline</title>',
#  '<title>MediaWiki:Unusedimagestext</title>',
#  '<title>MediaWiki:Usercssjsyoucanpreview</title>',
#  '<title>MediaWiki:Viewsource</title>',
#  '<title>MediaWiki:Welcomecreation</title>',
#  '<title>Wikisource:Portada Primera</title>',
#  '<title>Plantilla:Infotexto</title>',
# ...

# %%
len(lista)
# Out:
# 1292

# %% [markdown]
# ### Obtener index de libros

# %%
lista_libros_index=[]
cont_libros_index=0


for path_index in glob('./Libros_Wiki/*'):
    name_book_index=1
    
    with open(path_index, 'r', encoding='utf-8') as file_index:
        
        #file_i_read = file_index.read()
        soup = BeautifulSoup(file_index, 'html.parser')
        text_clean = soup.get_text()
        
        if 'Índice auxiliar' in text_clean:
            print(path_index)
            n_replace = re.sub(r'\[\[|\]\]|<br>|</br>| ~| -|\* |\s*\(\d{4}\)|//|\*|Img=Vivientes-JuanJoséMorosoli.jpg|', '', text_clean)
            
            indice = ['{{Índice auxiliar|{{lista simple|','{{Índice auxiliar|título={{Anclaje+|Índice}}|{{lista simple|','{{Índice auxiliar|título={{Anclaje+|Índice}}|','{{Índice auxiliar|título={{Anclaje+|Índice de novelas}}|','{{Índice auxiliar|título=Índice|','{{Índice auxiliar|']
                
            for i in indice:
                if i in n_replace:
                    start_name = n_replace.find(i)
                    start_i = start_name + len(i)
                    text = n_replace[start_i:]
                    text = re.sub(r'\n+', '\n', text).strip('\n')
                    print('###'*40, '\n', text)
                    
                    name_path_index = re.sub(r'./Libros_Wiki\\', '', path_index)
                    
                    with open('./Libros_Wiki_Index/'+name_path_index, 'w',encoding='utf-8') as file_index:
                        file_index.write(text)
                    break
                    
            cont_libros_index+=1
print('Libros con index: ', cont_libros_index)
# Out:
# ./Libros_Wiki\Bichito de luz (libro).txt
# ########################################################################################################################
#  Bichito de luz (cuento)|Bichito de luz
# Badía hermanos
# La primera elección
# Zorros
# Monte
# Me quedo...
# Inocencia
# Por el catre
# A mano
# Los novios
# La mujer (Rodríguez)|La mujer
# Caso de conciencia
# Guachita
# Inés (Rodríguez)|Inés
# La respuesta (Rodríguez)|La respuesta
# }}
# Categoría:ES-B
# Categoría:Cuentos de Yamandú Rodríguez
# Categoría:P1925
# Categoría:Cuentos
# Categoría:Literatura uruguaya (Títulos)
# 58enytha019q31cespurdmyz9yzmfxg
# ./Libros_Wiki\Brisas de primavera.txt
# ########################################################################################################################
#  El retrato vivo
# Pedro y Perico
# El pozo mágico
# La copa encantada
# El paje Roger
# La rosa blanca
# La hija del gigante
# El altar de la Virgen
# La princesa Elena
# El perro del ciego
# ...

# %% [markdown]
# ### Extraer libros de los indices

# %%
with open('C:/Users/Yael/Downloads/eswikisource-20240701-pages-articles-multistream.xml','r',encoding='utf-8') as books_file_:
    books_cont = books_file_.read()  

contador_index_books = 0

for index_name_path in glob('./Libros_Wiki_Index/*'):
    name_path_index_clean = re.sub(r'./Libros_Wiki_Index\\|.txt', '', index_name_path)
    print(index_name_path)
    
    
    with open(index_name_path, 'r', encoding='utf-8') as index_file:
        index_file = index_file.readlines()
        
        name_index_book = [line.replace('\n', '') for line in index_file]
        name_index_book = [line_.strip() for line_ in name_index_book]
        
        for name_i in name_index_book:
            next_title=0
            current_title=0
            
            start_book=0
            end_book=0
            
            name_clean_book=''
            name_i_without_or = re.sub(r"\|+.*|'''", "", name_i)

            book_title = f'<title>{name_i}</title>'

            book_title_without_or = f'<title>{name_i_without_or}</title>'

            book_title_without_or_plus_name_book = f'<title>{name_path_index_clean+name_i_without_or}</title>'


            if book_title in lista_titles_all:
                current_title=lista_titles_all.index(book_title)
                next_title = current_title+1

                try:
                    
                    start_book = books_cont.find(lista_titles_all[current_title])
                    end_book = books_cont.find(lista_titles_all[next_title])            

                    contador_index_books += 1
                    name_clean_book = re.sub(r'<title>|</title>','',book_title)
                    name_clean_book = re.sub(r'[\\/*?:"<>|]','-',name_clean_book)

                    with open('./Libros_Wiki_Index_Content/'+name_clean_book+'.txt', 'w', encoding='utf-8') as write_book:
                        write_book.write(books_cont[start_book:end_book])

                    print('Guardado: ', book_title)
                except:
                    print('no esta: ', book_title)



            else:

                if book_title_without_or in lista_titles_all:

                    contador_index_books += 1
                    name_clean_book = re.sub(r'<title>|</title>','',book_title_without_or)
                    name_clean_book = re.sub(r'[\\/*?:"<>|]','-',name_clean_book)

                    try:
                        
                        current_title=lista_titles_all.index(book_title_without_or)
                        next_title = current_title+1

                        start_book = books_cont.find(lista_titles_all[current_title])
                        end_book = books_cont.find(lista_titles_all[next_title])   

                        with open('./Libros_Wiki_Index_Content/'+name_clean_book+'.txt', 'w', encoding='utf-8') as write_book:
                            write_book.write(books_cont[start_book:end_book])

                        print('Guardado: ', book_title_without_or)
                    except:
                        print('no esta: ', book_title_without_or)

                else:
                    if book_title_without_or_plus_name_book in lista_titles_all:
                        contador_index_books += 1
                        name_clean_book = re.sub(r'<title>|</title>','',book_title_without_or_plus_name_book)
                        name_clean_book = re.sub(r'[\\/*?:"<>|]','-',name_clean_book)
                        
                        try:

                            current_title=lista_titles_all.index(book_title_without_or_plus_name_book)
                            next_title = current_title+1

                            start_book = books_cont.find(lista_titles_all[current_title])
                            end_book = books_cont.find(lista_titles_all[next_title])   

                            with open('./Libros_Wiki_Index_Content/'+name_clean_book+'.txt', 'w', encoding='utf-8') as write_book:
                                write_book.write(books_cont[start_book:end_book])

                            print('Guardado: ', book_title_without_or_plus_name_book)
                        except: 
                            print('no se encontro el libro: ', book_title_without_or_plus_name_book)


        print('numero de libros: ', contador_index_books)
# Out:
# ./Libros_Wiki_Index\Bichito de luz (libro).txt
# Guardado:  <title>Bichito de luz (cuento)</title>
# Guardado:  <title>Badía hermanos</title>
# Guardado:  <title>Inocencia</title>
# Guardado:  <title>Los novios</title>
# Guardado:  <title>Categoría:ES-B</title>
# Guardado:  <title>Categoría:Cuentos de Yamandú Rodríguez</title>
# Guardado:  <title>Categoría:P1925</title>
# Guardado:  <title>Categoría:Cuentos</title>
# Guardado:  <title>Categoría:Literatura uruguaya (Títulos)</title>
# numero de libros:  9
# ./Libros_Wiki_Index\Brisas de primavera.txt
# Guardado:  <title>El retrato vivo</title>
# Guardado:  <title>Pedro y Perico</title>
# Guardado:  <title>El pozo mágico</title>
# Guardado:  <title>La copa encantada</title>
# Guardado:  <title>El paje Roger</title>
# Guardado:  <title>La rosa blanca</title>
# Guardado:  <title>La hija del gigante</title>
# Guardado:  <title>El altar de la Virgen</title>
# Guardado:  <title>La princesa Elena</title>
# ...

# %% [markdown]
# ### Limpiar texto

# %%
extra_text=[]
extract_text=[]
start_text = []
list_charct = ['.', ',', ';', ':', '?', '!', "'", '"','(', ')', '[', ']', '{', '}','—', '-', '_', '/', '\\', '*','+', '−', '=', '%', '&', '$', '#', '@', '~', '^', '<', '>', '|', '¨', '×', '÷', '√', '‹', '›']

contador=0
contador_indice = 0


list_of_files = filter( os.path.isfile, glob('./Libros_Wiki/*') ) 

#list_of_files = filter( os.path.isfile, glob('./Libros_Wiki_Index_Content/*') ) 

  
# Sort list of files in directory by size  
list_of_files = sorted( list_of_files, key =  lambda x: os.stat(x).st_size, reverse=True) 
  
# Iterate over sorted list of file names 
# and print them along with size one by one  
for path_of_file in list_of_files: 
    #print(path_of_file)   
    file_b = ''
    tt = []
    
    if extra_text:
        del extra_text [:]
        
    if extract_text:
        del extract_text [:]
            
    if start_text:
        del start_text [:]
    
    if tt:
        del tt [:]


    name_file_clean = re.sub(r'./Libros_Wiki\\|.txt', '', path_of_file)
    
    #name_file_clean = re.sub(r'./Libros_Wiki_Index_Content\\|.txt', '', path_of_file)
    
    
    name_file_clean = re.sub(r'[\\/*?:"<>|]','-',name_file_clean)
    
    
    
    with open(path_of_file, 'r', encoding='utf-8') as file_b:
        file_b = file_b.read()
        file_b = re.sub(r'<sha1>.*?</sha1>', '', file_b)        
        
        cont_first_dot=0
        cont_neardot = 0
        
        soup = BeautifulSoup(file_b, 'html.parser')
        file_b = soup.get_text()

       
        file_b = re.sub(r'\[\[Category:(.*?)\]\]|\[\[Categoría:(.*?)\]\]|sha1(.*?)','', file_b)
        file_b = re.sub('align=&quot;right&quot;|align="right"|[0-9]{1,3}|<.*?>|{{Página línea|label=}}|{{Brecha\|[0-9]{1,3}|em}}', '', file_b)
        
        file_b = re.sub(r'align = |" right "| [0-9]{1,3}|\]{1,2}|\[{1,2}|#|--T::Z|wikitext|text/x-wiki|Fix errores HTML.|BOTicias|NinoBot','',file_b)
        file_b = re.sub(r'\|',' ',file_b)
        file_b = re.sub(r'\s+', ' ', file_b)
    
        
        file_b = re.sub('{{.*?}}|{ width="%"|Bot: sustitución de la plantilla: Encabezado|Bot : cambio de la plantilla : Encabe|Derechos Reservados. Queda prohibida la reproducción o transmisión total o parcial del texto y de las ilustraciones de la presente obra en cualesquiera formas de impresión; sean electrónicas o mecánicas, presentes o futuras, sin el consentimiento previo y por escrito del autor. IMPRESO EN MEXICO PRINTED IN MEXICO LOS GUIÑOS DEL PASADO', '', file_b)

        
        file_b = re.sub(r'\n', '', file_b)
        
        tt = file_b.split(' ')        

        ultima_linea = file_b.rfind('\n')

        texto_sin_ultima_linea = file_b[:ultima_linea]
        
        if len(tt)>=500:
            with open(f"./Libros_Limpios/{name_file_clean}.txt", 'w', encoding='utf-8') as f_clean:
                f_clean.write(texto_sin_ultima_linea)
# Out:
# <>:59: SyntaxWarning: invalid escape sequence '\|'
# <>:59: SyntaxWarning: invalid escape sequence '\|'
# C:\Users\Yael\AppData\Local\Temp\ipykernel_11468\3037424629.py:59: SyntaxWarning: invalid escape sequence '\|'
#   file_b = re.sub('align=&quot;right&quot;|align="right"|[0-9]{1,3}|<.*?>|{{Página línea|label=}}|{{Brecha\|[0-9]{1,3}|em}}', '', file_b)

# %% [markdown]
# ### Obtener partes de libros

# %%
extra_text=[]
extract_text=[]
start_text = []
list_charct = ['.', ',', ';', ':', '?', '!', "'", '"','(', ')', '[', ']', '{', '}','—', '-', '_', '/', '\\', '*','+', '−', '=', '%', '&', '$', '#', '@', '~', '^', '<', '>', '|', '¨', '×', '÷', '√', '‹', '›']

contador=0
contador_indice = 0


list_of_files = filter( os.path.isfile, glob('./Libros_Wiki/*') ) 

#list_of_files = filter( os.path.isfile, glob('./Libros_Wiki_Index_Content/*') ) 

  
# Sort list of files in directory by size  
list_of_files = sorted( list_of_files, key =  lambda x: os.stat(x).st_size, reverse=True) 
  
# Iterate over sorted list of file names 
# and print them along with size one by one  
for path_of_file in list_of_files: 
    #print(path_of_file)   
    file_b = ''
    tt = []
    
    if extra_text:
        del extra_text [:]
        
    if extract_text:
        del extract_text [:]
            
    if start_text:
        del start_text [:]
    
    if tt:
        del tt [:]
        
#for path_file in glob('./Libros_Wiki/*'):

    name_file_clean = re.sub(r'./Libros_Wiki\\|.txt', '', path_of_file)
    
    #name_file_clean = re.sub(r'./Libros_Wiki_Index_Content\\|.txt', '', path_of_file)
    
    
    name_file_clean = re.sub(r'[\\/*?:"<>|]','-',name_file_clean)
    
    
    
    with open(path_of_file, 'r', encoding='utf-8') as file_b:
        file_b = file_b.read()
        file_b = re.sub(r'<sha1>.*?</sha1>', '', file_b)                 
        
        cont_first_dot=0
        cont_neardot = 0
        
        soup = BeautifulSoup(file_b, 'html.parser')
        file_b = soup.get_text()
                
        file_b = re.sub(r'\[\[Category:(.*?)\]\]|\[\[Categoría:(.*?)\]\]|<sha1>(.*?)</sha1>','', file_b)
        
        file_b = re.sub('align=&quot;right&quot;|align="right"|[0-9]{1,3}|<.*?>|{{Página línea|label=}}|{{Brecha\|[0-9]{1,3}|em}}', '', file_b)
        file_b = re.sub(r'align = |" right "| [0-9]{1,3}|\]{1,2}|\[{1,2}|#|--T::Z|wikitext|text/x-wiki|Fix errores HTML.|BOTicias|NinoBot','',file_b)
        file_b = re.sub(r'\|',' ',file_b)
        file_b = re.sub(r'\s+', ' ', file_b)
    
        
        file_b = re.sub('{{.*?}}|{ width="%"|Bot: sustitución de la plantilla: Encabezado|Bot : cambio de la plantilla : Encabe|Derechos Reservados. Queda prohibida la reproducción o transmisión total o parcial del texto y de las ilustraciones de la presente obra en cualesquiera formas de impresión; sean electrónicas o mecánicas, presentes o futuras, sin el consentimiento previo y por escrito del autor. IMPRESO EN MEXICO PRINTED IN MEXICO LOS GUIÑOS DEL PASADO', '', file_b)
        
        file_b = re.sub(r'\n', '', file_b)
        
        tt = file_b.split(' ')        

        
        num_rand = random.randint(500 ,5000)
        len_file = len(tt)
        
        #encontrar el punto aleatorio antes de los 500 
        
        if len_file>=500:   #
            num_rand_start_text = random.randint(0, len(tt)-500)
            

            if tt[0] in list_charct:
                del tt[0]
            
            end_text = num_rand_start_text+num_rand
            
            
            while end_text>len_file:
                
                num_rand = random.randint(500 ,5000)
                num_rand_start_text = random.randint(0, len(tt)-500)
                end_text = num_rand_start_text+num_rand
                


            start_text = tt[ num_rand_start_text :end_text]

            for first_do_sent in start_text:
                cont_first_dot+=1
                if first_do_sent.endswith('.'):
                    #print(first_do_sent)
                    start_text = start_text[cont_first_dot:]
                    #print(cont_first_dot)
                    
                    break

            extra_text.extend(tt[end_text:]) #extra es el texto sobrante del texto complto

            
            for near_dot in extra_text:
                cont_neardot+=1
                if near_dot.endswith('.') or near_dot == '.':
                    break

            start_text.extend(extra_text[:cont_neardot])
            
            with open('./Partes extraidas/'+name_file_clean+'.txt', 'w', encoding='utf-8') as parts_file:
                parts_file.write(' '.join(start_text))
            
            
            
        
        else:
            contador+=1
            print(name_file_clean, '----->', len_file)
        

            
            
print('Numero de libros sin texto: ',contador)
print('Numero de libros con indice: ', contador_indice)
# Out:
# <>:60: SyntaxWarning: invalid escape sequence '\|'
# <>:60: SyntaxWarning: invalid escape sequence '\|'
# C:\Users\Yael\AppData\Local\Temp\ipykernel_11468\218359781.py:60: SyntaxWarning: invalid escape sequence '\|'
#   file_b = re.sub('align=&quot;right&quot;|align="right"|[0-9]{1,3}|<.*?>|{{Página línea|label=}}|{{Brecha\|[0-9]{1,3}|em}}', '', file_b)
# El libro de los cuentos -----> 9
# Facundo (Güiraldes) -----> 484
# Acuarela 2 -----> 476
# Muro dobleancho -----> 466
# Conde Lucanor -----> 285
# Breve historia veraz de un pericote -----> 470
# El diablo y sus añicos -----> 451
# Arenero -----> 482
# Justo José -----> 406
# Venganza (Güiraldes) -----> 421
# El tío Cerote -----> 452
# La siesta de los zopilotes -----> 405
# Acuarela 1 -----> 425
# Un retrato de Watteau -----> 440
# La muerte del copinol -----> 372
# El arte del secuestro -----> 394
# La princesa sobre el guisante -----> 382
# Los juguetes -----> 415
# El Padre Postas -----> 416
# Una visita infernal -----> 417
# ...

# %% [raw]
# Libros index
#
#
# Cuesta abajo (Leopoldo Alas)-Día 7 de enero de 18... -----> 177
# Cuesta abajo (Leopoldo Alas)-Día 8 de enero de 18... -----> 167
# Cuesta abajo (Leopoldo Alas)-Día 9 de enero de 18... -----> 153
# Cuesta abajo (Leopoldo Alas)-Día 10 de enero de 18... -----> 137
# El clavo-XVII -----> 494
# Cuesta abajo (Leopoldo Alas)-Día 12 de enero de 18... -----> 121
# Cuesta abajo (Leopoldo Alas)-Día 14 de enero de 18... -----> 105
# Facundo (Güiraldes) -----> 484
# Chamijo- 10 -----> 492
# Al Ecce-Homo -----> 451
# Conde Lucanor-Ejemplo 16 -----> 477
# Doctor Angelicus-Capítulo II -----> 479
# Cisóforo el mago -----> 480
# Conde Lucanor-Ejemplo 37 -----> 455
# Conde Lucanor-Ejemplo 31 -----> 464
# Muro dobleancho -----> 466
# Soluciones de los acertijos populares -----> 441
# La Miraflores-X -----> 490
# Conde Lucanor-Ejemplo 8 -----> 422
# El tío Cerote -----> 452
# Arenero -----> 482
# Justo José -----> 406
# Conde Lucanor-Ejemplo 34 -----> 411
# Venganza (Güiraldes) -----> 421
# Conde Lucanor-Anteprólogo -----> 432
# La tentación -----> 454
# Los seis velos-VI -----> 354
# Pico, pico, a ver si me pongo rico -----> 470
# ¿Dónde está mi cabeza--VI -----> 310
# El arte del secuestro -----> 394
# Cuesta abajo (Leopoldo Alas)-Día 15 de enero de 18... -----> 89
# El Padre Postas -----> 416
# Los juguetes -----> 415
# Conde Lucanor-Ejemplo 39 -----> 381
# De la comisión- 03 -----> 390
# La virgen y el niño Jesús -----> 398
# El doctor Pértinax- 1 -----> 363
# La prez en el surco -----> 396
# El chico de la tienda -----> 388
# Los seis velos-Prólogo -----> 343
# El garcero -----> 361
# Saetas de Semana Santa -----> 326
# Esgarrachupas -----> 372
# Los hijos -----> 360
# Charadas -----> 378
# Asuntos religiosos -----> 226
# El cura de vericueto-Segunda parte-V -----> 359
# La Virgen costurera -----> 393
# La reina de la aguja -----> 351
# El lirio azul -----> 402
# Un refrán mal aplicado -----> 357
# Las armas de la victoria -----> 353
# El Zurdo -----> 344
# La galería de las máquinas -----> 382
# La chacra -----> 307
# El novelista -----> 320
# La col y la caldera -----> 359
# La industria -----> 321
# La lluvia (Morosoli) -----> 333
# La zorra y la vejeta -----> 370
# El galleguito -----> 325
# Las cañadas -----> 292
# Conversión de San Agustín -----> 260
# El león enjaulado -----> 323
# Los emigrantes -----> 314
# La pasión de Jesucristo -----> 266
# Por tropezar con una piedra -----> 302
# Alféizar -----> 298
# Desprecio de las advertencias -----> 323
# El domador (Morosoli) -----> 301
# Muro Este -----> 290
# La querencia olvidada -----> 279
# Los dos caminitos -----> 323
# El camino (Morosoli) -----> 272
# Acto de amor compuesto por una monja -----> 246
# El guacho (Morosoli) -----> 250
# Antes de leer -----> 274
# El aguatero -----> 266
# El cura de vericueto-Primera parte-VI -----> 275
# Los dos príncipes -----> 196
# Cuesta abajo (Leopoldo Alas)-Día 16 de enero de 18... -----> 73
# Si Dios quiere -----> 298
# Máximas que repetía un excelente padre a sus hijos -----> 284
# Los novios -----> 223
# Los carboneros -----> 235
# La varona de Castilla -----> 257
# Coplas de Nochebuena -----> 209
# Los boyeros -----> 241
# El animal prodigioso -----> 250
# Doctor Angelicus-Capítulo IV -----> 227
# El consonante -----> 239
# Las gafas -----> 238
# Relaciones religiosas -----> 216
# El carrero -----> 228
# Sinfonía -----> 183
# Cómo le gusta al Niño Dios que le pidan -----> 252
# A quién debe darse crédito -----> 237
# Las castañas (Juan Valera) -----> 212
# Creación de la golondrina -----> 243
# Extraña manutención militar -----> 203
# Otra versión del Carlanco -----> 235
# El verdugro barato -----> 35
# La geografía -----> 198
# Milagro de la dialéctica -----> 217
# El gitano teólogo -----> 205
# San Pedro -----> 216
# El famoso cantor Madureira -----> 171
# Señor, aquí está Juan -----> 200
# Cuervo (Clarín)- 01 -----> 184
# El clavo-XVIII -----> 72
# El gloria patri -----> 187
# Las caballadas -----> 162
# La oración del simple -----> 158
# Inocencia -----> 164
# Cada uno a su oficio -----> 143
# Manifestaciones de duelo del Rey de Portugal -----> 154
# Fecundidad de la memoria -----> 149
# Fabla salvaje-VIII -----> 150
# La bruja del ideal- 02 -----> 29
# El duendecillo fraile -----> 156
# Jesús al alma -----> 138
# Cuento de bruja -----> 162
# El gallo y el pato -----> 159
# Interpretación de un texto latino -----> 132
# La karaba -----> 135
# Oraciones, relaciones y coplas infantiles -----> 114
# Vivientes- Prefacio -----> 6
# El holgazán -----> 140
# El clavo -----> 7
# El árbol en el campo -----> 122
# Memorial que presentó á un Grande de España al abogado Silvio del Arga -----> 25
# Doña Bishodie -----> 121
# La gallina duende -----> 144
# Cuesta abajo (Leopoldo Alas)-Día 11 de enero de 18... -----> 24
# El músico de Mitrídates -----> 17
# El consuelo de la albarda -----> 15
# La rosa blanca -----> 45
# La necesidad de puntuar bien -----> 17
# Cuentos para gente menuda-Prólogo -----> 111
# Un amor romántico curado con aceite -----> 16
# El peluquero burlado -----> 13
# Adán -----> 113
# Vivientes -----> 50
# Verdaderas cuentas del Gran Capitán -----> 15
# La lengua de las mujeres -----> 15
# Célebres cartas atribuidas á un Dean de Cuenca y un cura de Pareja -----> 23
# El Miércoles de Ceniza -----> 14
# Datos biográficos de Adam -----> 15
# La nariz escalera -----> 14
# La instrucción de un pastor -----> 16
# La justicia de Marruecos -----> 15
# Una misa corta -----> 14
# Ejemplos -----> 117
# La curación de un mal genio -----> 17
# Contra el mal de suegro -----> 15
# La anguila á cuenta de palos -----> 17
# El pleito de la cabra -----> 16
# El rey y el cura de aldea -----> 18
# El zapatero y la cabeza cortada -----> 17
# San Lorenzo -----> 112
# La compra de una burra -----> 16
# La confianza de un hombre generoso -----> 16
# El burro encantado -----> 14
# El canto gangoso -----> 101
# Carta de una mujer enamorada -----> 15
# El rey levantando un burro -----> 16
# El aumento del prefacio -----> 14
# El leñador honrado -----> 14
# El sermón perdido -----> 14
# Un perro pancista -----> 14
# Los tres asientos en la diligencia -----> 16
# Lamentos de un paleto por la pérdida de su burra -----> 20
# Carlos III y su paje -----> 16
# Secretos de naturaleza, sorprendentes y de infalible resultado -----> 18
# Las alforjas cosidas y descosidas -----> 15
# La esplicacion de un zapatero -----> 15
# El predicador y el albeitar -----> 15
# La inocencia discreta -----> 13
# La vieja á caballo sobre un cerdo -----> 17
# El carro de paja y el hombre -----> 17
# La esplicacion de un delito -----> 15
# La habilidad de hallar dinero -----> 15
# Epitafios portugueses -----> 12
# La mediación de un cordero -----> 15
# La modestia zapatera -----> 13
# La razón de la sinrazón -----> 14
# El hombre disfrazado de pájaro -----> 15
# El pobre y los ladrones -----> 15
# El temor de sí mismo -----> 15
# La malicia de los pavos -----> 15
# A un favor otro igual -----> 15
# El mondadientes -----> 12
# El soldado arqueólogo -----> 13
# Los pasados y los presentes -----> 15
# El perdón fingido -----> 13
# Enigmas 5 (El libro de los cuentos) -----> 16
# La arenga de un alcalde -----> 15
# La prudencia de una nuera -----> 15
# El caballero de Madrid y el de provincia -----> 18
# El Emperador y el poeta -----> 15
# Pensamientos persas -----> 12
# Las misas de un testamento -----> 15
# Los dos sonetos peores -----> 14
# El judío y el dia de fiesta -----> 17
# La oración de una vieja -----> 15
# Nuevo metodo de sacar muelas -----> 15
# Un grande hombre vengándose como un niño -----> 17
# A cada uno lo suyo -----> 15
# Los monos y las peras -----> 15
# Pensamientos 1 (El libro de los cuentos) -----> 16
# El amigo desconocido -----> 13
# El incrédulo y la medicina -----> 15
# La elección de un cuadro -----> 15
# Morir por falta de memoria -----> 15
# De consejo muda el sabio -----> 15
# El labrador y la linterna -----> 15
# La contestación á una insolencia -----> 15
# La prueba de la locura -----> 15
# La fealdad de Simónides -----> 14
# La mujer del literato -----> 14
# Adivinanzas 17 (El libro de los cuentos -----> 16
# El recogido en la calle -----> 15
# La confesión de una casada -----> 15
# La libertad á tiros -----> 14
# La suegra y la nuera -----> 15
# El canónigo y el ladron de trigo -----> 17
# El hurto de un par de botas -----> 17
# La curiosidad exagerada -----> 13
# No hay peor sordo... -----> 14
# Comer para morir -----> 13
# El ejercicio de fuego de un recluta -----> 17
# El reloj gusano -----> 13
# La economía doméstica -----> 13
# La satisfacción bien dada -----> 14
# La supresión del tiempo -----> 14
# Cada uno sabe dónde le aprieta, etc -----> 17
# Economía estudiantil -----> 12
# El dinero y el vino -----> 15
# La sagacidad de un tonto -----> 15
# Previsión de un ajusticiado -----> 14
# El amo rico y el criado fuerte -----> 17
# El descansar fuera de tiempo -----> 15
# Los zapatos roidos por los ratones -----> 16
# Enigmas 7 (El libro de los cuentos) -----> 16
# Las cabezas de borrico -----> 14
# Adivinanzas 10 (El libro de los cuentos -----> 15
# Enigmas 12 (El libro de los cuentos) -----> 16
# El parecido completo -----> 13
# El sermón de una kuákara -----> 15
# La murmuración de los borrachos -----> 15
# Un padre de talento -----> 14
# A mucho fuego mucha agua -----> 15
# El llanto justo -----> 13
# El oficial de porcelana -----> 14
# La cabeza escondida -----> 13
# La exactitud de un portero -----> 15
# Pensamientos 2 (El libro de los cuentos) -----> 16
# El criado dormilón -----> 13
# El loco y el podenco -----> 15
# Para que no haga daño el chocolate, aun cuando la chocolatera sea de cobre y esté sin estañar -----> 27
# Tal para cual -----> 13
# El tonto y el mosquito -----> 15
# Los celos de un hombre pacífico -----> 16
# El casco del dragón -----> 14
# El descamisado -----> 12
# El jubileo -----> 12
# El reparto del hambre -----> 14
# La hermana muerta y la viva -----> 16
# La música en el entierro -----> 15
# La proposición de un negocio -----> 15
# Receta para desatascar un coche simen -----> 16
# Consejos para las novias -----> 14
# El engañador engañado -----> 13
# El yerro de un cazador -----> 15
# La indirecta de un suegro -----> 15
# La pena del talion -----> 14
# Lo preciso y lo difuso -----> 15
# El maestro de Cisneros -----> 14
# El peluquín á la moda -----> 15
# La exageración cortada por mitad -----> 15
# Papeles viejos -----> 12
# Consejo de mujer -----> 13
# El insulto rechazado -----> 13
# La cena por la mañana -----> 15
# El caldo entre piedras -----> 14
# La nariz cortada y pegada -----> 15
# Lo que se entiende por desafinar -----> 16
# Los paréntesis -----> 12
# Los tres oficios del barbero -----> 15
# Decir que sí ó á la cárcel -----> 17
# El cabello de la Virgen -----> 15
# El encuadernador y el presidiario -----> 15
# El espíritu de contradicción -----> 14
# El examen del paleto -----> 14
# El fusilamiento á peseta -----> 14
# El sombrero de Carlos III -----> 15
# La venganza de un marido -----> 15
# El arre del filósofo -----> 14
# El caballo curandero -----> 13
# El criado recien venido -----> 14
# La boticaria y la medicina -----> 15
# La declaración indagatoria -----> 13
# La memoria del estómago -----> 14
# Las cosas supérfluas -----> 13
# Santa Teresa y las elecciones -----> 15
# La ciudad de las tabernas -----> 15
# La confesión de un ratero -----> 15
# La imposibilidad de llorar -----> 14
# La mujer descalabrada -----> 13
# Los comestibles mas baratos -----> 14
# El alcalde y su burro -----> 15
# El amor de afinidad -----> 14
# El caballo de Pauson -----> 14
# El convite económico -----> 13
# La carta de un ahorcado -----> 15
# La industria de un pobre -----> 15
# La piedad de una viuda -----> 15
# La sentencia de un alcalde -----> 15
# El caballo de regalo -----> 14
# El contrabandista delator -----> 13
# El estudiante haciendo huevos -----> 14
# El gobernador y el alcalde -----> 15
# El hijo filósofo -----> 13
# El peine de asta -----> 14
# El testamento interpretado -----> 13
# El valentón -----> 12
# La discusión concejil -----> 13
# La duración del placer -----> 14
# La oratoria nueva -----> 13
# La orden militar -----> 13
# La superchería -----> 12
# Lo tratado es tratado -----> 14
# Los doce pares de Francia -----> 15
# Un acreedor de lo que no hay -----> 17
# Abrir al que llama -----> 14
# El efecto de las barrajas -----> 15
# La hermosura á pedazos -----> 14
# La sombra del asno -----> 14
# Las pildoras sánalo todo -----> 14
# Los toros -----> 12
# Un negocio mejorable -----> 13
# Un tiro difícil -----> 13
# El convidado y el cubierto -----> 15
# El cortaplumas perdurable -----> 13
# El don detrás y delante -----> 15
# El error del pié -----> 14
# El parentesco decente -----> 13
# La diferencia en el medir -----> 15
# La molinera en el rio -----> 15
# La mujer de Sócrates -----> 14
# Una cabeza de espediente -----> 14
# Una pequeña dificultad -----> 13
# El apóstol correo -----> 13
# El aumento de valor -----> 14
# El dolor acomodaticio -----> 13
# El hombre mas feo -----> 14
# El olvido de sí mismo -----> 15
# La carne podrida -----> 13
# Pensamientos profundos -----> 12
# El respeto al público -----> 14
# El tesoro (Boira) -----> 13
# En medicina, la fé -----> 14
# La astucia de la mujer -----> 15
# La justicia y el puerco -----> 15
# Receta para los ojos -----> 14
# Una sola pregunta -----> 13
# El amor de ultratumba -----> 14
# El chocolate ayudado -----> 13
# El juego de prendas -----> 14
# El lenguaje de las peces -----> 15
# El paleto en el teatro -----> 15
# Exageraciones -----> 11
# Felipe II y su favorito -----> 15
# Historias y cuentos de Galicia -----> 77
# Morderse las orejas -----> 13
# Una precaución sabia -----> 13
# El exámen de doctrina -----> 14
# La cara de un feo -----> 15
# El alma de Pero-Nuñez -----> 14
# La botica vestida de novia -----> 15
# La cuenta cabal -----> 13
# La zarza alguacil -----> 13
# El aceite de la lámpara -----> 15
# El celoso enfermo -----> 13
# El hermano y la hermana -----> 15
# El hijo fraile -----> 13
# El poeta herrador -----> 13
# El hurto incompleto -----> 13
# El primer sermón -----> 13
# El rey sarmentador -----> 13
# El rey y el paleto -----> 15
# El cubo de chocolate -----> 14
# El salón de Apolo -----> 14
# El santo del dia -----> 14
# Las medias de una criada -----> 15
# El hurto del vino -----> 14
# Gastar con prudencia -----> 13
# La hermosa sin boca -----> 14
# Buscar la lengua -----> 13
# El a b y el c d -----> 17
# El gato cocinero -----> 13
# Las malas lenguas -----> 13
# Ni pies ni cabeza -----> 14
# El amo burlado -----> 13
# El nombre apelativo -----> 13
# El novicio jugador -----> 13
# Esperanza de un zapatero -----> 13
# El ladrón de huevos -----> 14
# El rey y Quevedo -----> 14
# La poca ropa -----> 13
# Las medias del revés -----> 14
# Las siete cabrillas -----> 13
# El perro novio -----> 13
# Refranes -----> 11
# El cazador sediento -----> 13
# El miedo del marido -----> 14
# Para que los ratones se maten ellos mismos -----> 17
# El casamiento imposible -----> 13
# La contestación hábil sin entender la pregunta -----> 16
# La profunda habilidad de dos concejales -----> 15
# La equivocación -----> 12
# Una alcaldada -----> 12
# Esperanzas de estudiante -----> 12
# Adivinanzas 1 (El libro de los cuentos) -----> 15
# Contestación de un embajador -----> 13
# La predicción -----> 12
# Modelo de cartas conyuguales -----> 13
# Adivina -----> 91
# Bagajes -----> 91
# Adivinanzas 8 (El libro de los cuentos) -----> 15
# El paraíso de los moros -----> 14
# El registro de necedades -----> 13
# Adivinanzas 14 (El libro de los cuentos -----> 15
# La sencillez de un niño -----> 14
# El diablo y el novicio -----> 14
# La pregunta de doble sentido -----> 14
# Adivinanzas 13 (El libro de los cuentos -----> 15
# La escasez de cuernos -----> 13
# El vino bueno -----> 12
# La esplicacion innecesaria -----> 12
# Pensamiento 6 (El libro de los cuentos) -----> 15
# Adivinanzas 18 (El libro de los cuentos -----> 15
# La razón perdiendo -----> 12
# Lo que es gollería en una venta -----> 16
# Adivinanzas 15 (El libro de los cuentos -----> 15
# Adivinanzas 2 (El libro de los cuentos) -----> 15
# Adivinanzas 7 (El libro de los cuentos -----> 15
# Esopo segundo -----> 11
# La perla de la mora -----> 66
# La risa (Boira) -----> 12
# Lo mismo la pena que el delito -----> 16
# El justo por el pecador -----> 14
# Los dos lados de todas las cuestiones -----> 16
# Una buena mujer -----> 12
# El suelto que no se puede prender -----> 16
# La perfección de la imperfección -----> 14
# Adivinanzas 19 (El libro de los cuentos -----> 15
# Adivinanzas 3 (El libro de los cuentos) -----> 15
# Adivinanzas 4 (El libro de los cuentos) -----> 15
# Diferencia entre la y griega y la i latina -----> 18
# El espanta-pájaros -----> 11
# El sacramento del matrimonio -----> 13
# La aflicción de una viuda -----> 14
# Enigmas 4 (El libro de los cuentos) -----> 15
# La agudeza de un loco -----> 14
# Tutearse para despedirse -----> 12
# Enigmas 13 (El libro de los cuentos) -----> 15
# La equivocación de un verdugo -----> 14
# Pensamientos 5 (El libro de los cuentos) -----> 15
# Enigmas 16 (El libro de los cuentos) -----> 15
# Enigmas 17 (El libro de los cuentos) -----> 15
# La alegría para todos -----> 13
# La contestación sutil -----> 12
# Lo bueno y lo malo del madrugar -----> 16
# Adivinanzas 16 (El libro de los cuentos -----> 15
# El asesinato por amor -----> 13
# El curioso por su mal -----> 14
# Enigmas 15 (El libro de los cuentos) -----> 15
# Una buena sopa -----> 12
# El enfermo regateando su entierro -----> 14
# El francés y los españoles -----> 14
# El premio de la memoria -----> 14
# Enigmas 14 (El libro de los cuentos) -----> 15
# La locura de casarse viejo -----> 14
# La murmuración en plural -----> 13
# La prueba (Boira) -----> 12
# Las cosas perdidas -----> 12
# Lo que es un oso -----> 14
# Pensamientos 3 (El libro de los cuentos) -----> 15
# Adivinanzas 6 (El libro de los cuentos) -----> 15
# Enigmas 9 (El libro de los cuentos) -----> 15
# La muerte de una cuñada -----> 14
# Lo que no se puede enmendar, hacerlo nuevo -----> 17
# Adivinanzas 11 (El libro de los cuentos -----> 15
# Adivinanzas 5 (El libro de los cuentos) -----> 15
# El pueblo siempre es igual -----> 14
# La ortografía en las calcetas -----> 14
# La precaución acertada -----> 12
# El derecho de matar -----> 13
# El disfraz equivoco -----> 12
# El suicidio de un avaro -----> 14
# Enigmas 10 (El libro de los cuentos) -----> 15
# Enigmas 8 (El libro de los cuentos) -----> 15
# La reprimenda de un padre -----> 14
# Adivinanzas 9 (El libro de los cuentos -----> 15
# El parecer de la señora abogada -----> 15
# Enigmas 1 (El libro de los cuentos) -----> 15
# La escasez de doncellas -----> 13
# La pretensión imposible -----> 12
# La pérdida de un vecino -----> 14
# No se bate el dichoso -----> 14
# Para no tropezar estarse echado -----> 14
# El loco por la pena es cuerdo -----> 16
# Enigmas 11 (El libro de los cuentos) -----> 15
# Enigmas 18 (El libro de los cuentos) -----> 15
# Enigmas 19 (El libro de los cuentos) -----> 15
# La curiosidad de una niña -----> 14
# La economía práctica -----> 12
# La espada contra la reja -----> 14
# La oración del perezoso -----> 13
# Pensamientos 4 (El libro de los cuentos) -----> 15
# Una indirecta del padre Cobos -----> 14
# Enigmas 2 (El libro de los cuentos) -----> 15
# La cuenta igual -----> 12
# Los santos de medio cuerpo -----> 14
# De qué mujer debe tener celos un marido -----> 17
# El recibimiento de un comisionado de apremio -----> 16
# La apelación para ante el mismo juez -----> 16
# La escala jerárquica de los ladrones -----> 15
# El predicador sin auditorio -----> 13
# El procurador y el sastre -----> 14
# Enigmas 3 (El libro de los cuentos) -----> 15
# La abundancia de caza -----> 13
# Pensamientos con suerte -----> 12
# Relación entre el comer cebada y el rabo -----> 17
# Un buen remedio á falta de azotes -----> 16
# Dosear de palabra -----> 12
# El frasco pequeño -----> 12
# El tribunal de mujeres -----> 13
# Los aplausos de la muchedumbre -----> 14
# ¿Quién hallará la mujer fuerte- -----> 14
# Cuestión de gramática -----> 12
# Dichos célebres de Sócrates -----> 13
# El parentesco con la mula -----> 14
# La esperanza de ser diablo -----> 14
# La paciencia de un filósofo -----> 14
# La pérdida irreparable -----> 12
# Las herraduras en su lugar -----> 14
# El medio de hacer amigos -----> 14
# El predicador y el tamborilero -----> 14
# El primer día de viuda -----> 14
# El uso de condenarse -----> 13
# La ocupación de los criados -----> 14
# El destierro como un bien -----> 14
# El perdón por delante -----> 13
# El retrato de una muerta -----> 14
# La estratagema frustrada -----> 12
# La vuelta del que no marcha -----> 15
# Lo que vá y lo que se vá -----> 17
# Aunque no lo dijese -----> 13
# Conocer por el olfato -----> 13
# El hijo del pueblo -----> 13
# El portero alarmado -----> 12
# El puente sin pretiles -----> 13
# El valor de un torero -----> 14
# La adulación (Boira) -----> 12
# La curación completa -----> 12
# La ópera gratuita -----> 12
# Las vacas del asturiano -----> 13
# Los adornos exagerados -----> 12
# Una lección de abogacía -----> 13
# Adivinanzas 12 (El libro de los cuentos -----> 15
# Comentarios al Alcorán -----> 12
# El consejo de un sabio -----> 14
# El guia de la danza -----> 14
# El que á los suyos parece -----> 15
# El sacristán y su ayuda -----> 14
# El tratamiento -----> 11
# La censura de unos versos -----> 14
# La silba antes de tiempo -----> 14
# Lo que signifíca ventana -----> 13
# Un predicador miedoso -----> 12
# ¿Cuántos dioses hay- -----> 12
# El abrigo de cristal -----> 13
# El depósito comido -----> 12
# La razón del celibato -----> 13
# Las tiendas abiertas -----> 12
# Mujeres heroicas -----> 11
# Un literato sin letras -----> 13
# Uno es uno y otro es otro -----> 16
# ¿Es historia ó fábula- -----> 13
# Curar con ejemplos -----> 12
# El capitán y el soldado -----> 14
# El pantalón único -----> 12
# El regalo de Noche-buena -----> 13
# El retor y el vicario -----> 14
# La astucia de Mitrídates -----> 13
# La bestia mas grande -----> 13
# La cuenta de un italiano -----> 14
# La ronquera de una dama -----> 14
# La tos y los dientes -----> 14
# La virtud de la turquesa -----> 14
# Las dos religiones -----> 12
# Los versos pecadores -----> 12
# Un testamento original -----> 12
# Belleza contra talento -----> 12
# El acreedor y el deudor -----> 14
# El ciego y la luz -----> 14
# El contrato deshecho -----> 12
# El cura de vericueto -----> 88
# El ministro y las piruetas -----> 14
# El muerto escribiendo -----> 12
# La repetición del eclipse -----> 13
# La salud de un muerto -----> 14
# Un caballero instruido -----> 12
# El aprehensor prendido -----> 12
# El aprendiz de carnicero -----> 13
# El mayor mal de los males -----> 15
# El murmurador -----> 11
# El pacto con el verdugo -----> 14
# Examinar el sol con candil -----> 14
# La asadura á crédito -----> 13
# La pobreza de un rico -----> 14
# La pregunta escusada -----> 12
# Cómo sabe la perdiz -----> 13
# El burro astrólogo -----> 12
# El derecho de los hermanos -----> 14
# El fin del mundo -----> 13
# El pintor pica pleitos -----> 13
# El soldado y el perro -----> 14
# El tirador y el blanco -----> 14
# La caridad interesada -----> 12
# La cortedad de genio -----> 13
# La razón de no escribir -----> 14
# La réplica oportuna -----> 12
# Las desgracias reunidas -----> 12
# Lo que es una obra postuma -----> 15
# Los dos gabanes -----> 12
# Los rábanos -----> 11
# Necedades de gran valor -----> 13
# Aprender á nadar en seco -----> 14
# El arzobispo jóven -----> 12
# El chocolate en miniatura -----> 13
# El cojo y el jorobado -----> 14
# El jóven y las viejas -----> 14
# El moribundo y el acreedor -----> 14
# La berza y la caldera -----> 14
# La bomba convertida en salvadera -----> 14
# La fé de erratas -----> 13
# La relación de un andaluz -----> 14
# La subordinación militar -----> 12
# La traducción literal -----> 12
# Los frenos trocados -----> 12
# Los árboles del Paraiso -----> 13
# Pensamientos de Tháles -----> 12
# Una carta y una contestación -----> 14
# El caballo lector -----> 12
# El cartel -----> 11
# El efecto y la causa -----> 14
# El jubón del rey Católico -----> 14
# El muchacho despejado -----> 12
# El reloj atrasado -----> 12
# El secreto de naturaleza -----> 13
# El uso de las pistolas -----> 14
# Enigmas 6 (El libro de los cuentos) -----> 15
# La murmuración -----> 11
# La oreja de Alejandro -----> 13
# La paga de un sermón -----> 14
# La próroga del eclipse -----> 13
# El maldiciente -----> 11
# La bofetada -----> 11
# La cena á medio dia -----> 14
# La compra á deber -----> 13
# La religión verdadera -----> 12
# Los enemigos del alma -----> 13
# Pensamiento de un moro -----> 13
# Que lo ahorquen -----> 12
# San Cristóbal y el mundo -----> 14
# El arte de remozar -----> 13
# El cojo y su enemigo -----> 14
# El herrador y su idea -----> 14
# El noble y el plebeyo -----> 14
# El retrato leyendo -----> 12
# La edad de una hermosa -----> 14
# La muerte rogada -----> 12
# Las tripas corazón -----> 12
# Segunda sin primera -----> 12
# A un asombro otro mayor -----> 14
# Consejos para vivir mucho -----> 13
# El cabrito soltero -----> 12
# El paseo en la caja del reloj -----> 16
# La edad en los dientes -----> 14
# La mujer aguda -----> 12
# La pintura y el blanqueo -----> 14
# Las dos manolas -----> 12
# Los criados del rey -----> 13
# Los ladrones aconsejados -----> 12
# Los treinta años clavados -----> 13
# Los versos de un rey -----> 14
# Pensamiento ingenioso -----> 11
# Un perro barbero -----> 12
# El acertijo -----> 11
# El dormido despierto -----> 12
# El hombre infusorio -----> 12
# El marido sensible -----> 12
# Hágalo usted mejor -----> 12
# La nieve y las vacas -----> 14
# Los años no se roban -----> 14
# El ay del tesorero -----> 13
# El bibliotecario ignorante -----> 12
# Escipion y Ennio -----> 12
# Filipo y la vieja -----> 13
# La nobleza en la rueca -----> 14
# La purga pintada -----> 12
# Los tres enigmas -----> 12
# La costumbre es ley -----> 13
# La prudencia de un marido -----> 14
# La vírgen de parto -----> 13
# Un buen deseo -----> 12
# El adulterio en Esparta -----> 13
# El caballo tortuga -----> 12
# El dominosteco -----> 11
# Un bibliotecario sabio -----> 12
# Descaro para pedir -----> 12
# El hoyo grande -----> 12
# El ojo en la mano -----> 14
# La muerte de un cadáver -----> 14
# La paz y la guerra -----> 14
# Sobre favor, paga -----> 12
# El ojo hallado -----> 12
# El tuerto y el cojo -----> 14
# Un gran pensamiento -----> 12
# Una letra mas -----> 12
# El flato noble -----> 12
# El orgullo abatido -----> 12
# El plato valiente -----> 12
# El viajero universal -----> 12
# Los sabios aman -----> 12
# Un cero en medio -----> 13
# Zapatero á tus zapatos -----> 13
# El tocinero en el palco -----> 14
# La imitación -----> 11
# La mujer perdida -----> 12
# Las dos sordas -----> 12
# Los ciegos burlados -----> 12
# Tomar el parecido -----> 12
# Una verdad peligrosa -----> 12
# Augusto mal comido -----> 12
# El arpa del gitano -----> 13
# El fín del burro -----> 13
# La vida de fraile -----> 13
# Curiosidad de mujer -----> 12
# Dos sobrescritos -----> 11
# El pelo atado -----> 12
# El informe -----> 11
# La conformidad -----> 11
# La misa de alba -----> 13
# Las visiones -----> 11
# Vaya una duda -----> 12
# El vecino -----> 11
# El marrano y el burro -----> 14
# La razón convincente -----> 12
# Adivinanzas 20 (El libro de los cuentos) -----> 30
# Dos milagros (Martí) -----> 9
# El portugués que llegó a Cádiz -----> 68
# El portugués filólogo -----> 63
# La gallina del diablo -----> 7
# La bruja del ideal- 01 -----> 17
# De la comisión- 05 -----> 45
# La de los ojos color de uva -----> 73
# El labrador, el criado y su madre -----> 11
# Muro occidental -----> 28
# Fabla salvaje -----> 31
# Mis últimas tradiciones peruanas y Cachivachería -----> 11
# Vivientes- Dedicatoria -----> 8
# Reveladoras -----> 5
# Lo irreparable (Trigo) -----> 31
# Pipá -----> 6
# El diablo aprendiendo á freir huevos -----> 8
# El libro de los cuentos- 1 -----> 7
# El estudio fácil -----> 5
# Apéndice a Mis últimas tradiciones peruanas -----> 10
# Numero de libros sin texto:  782
# Numero de libros con indice:  0

# %% [markdown]
# ### Libros en Español

# %%
stops = set(stopwords.words('spanish'))
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 450

# %%
def find_spanish_books(path):
    text=[]
    cont_neardot = 0
    for i in glob(path):
        
        
        with open(i, 'r', encoding='utf-8') as file_b:
            #file_b = file_b.read()
            list_words=[]
            cont_word=0

            cont_first_dot=0
            
            
            words_in_stop = []

            soup = BeautifulSoup(file_b, 'html.parser')
            file_b = soup.get_text()

            file_b = re.sub('align=&quot;right&quot;|align="right"|[0-9]{1,3}|<.*?>|{{Página línea|label=}}|{{Brecha\|[0-9]{1,3}|em}}', '', file_b)
            file_b = re.sub(r'align = |" right "| [0-9]{1,3}|\]{1,2}|\[{1,2}|#|--T::Z|wikitext|text/x-wiki|Fix errores HTML.|BOTicias|NinoBot','',file_b)
            file_b = re.sub(r'\|',' ',file_b)
            file_b = re.sub('\s+', ' ', file_b)


            file_b = re.sub('{{.*?}}|{ width="%"|Bot: sustitución de la plantilla: Encabezado|Bot : cambio de la plantilla : Encabe|Derechos Reservados. Queda prohibida la reproducción o transmisión total o parcial del texto y de las ilustraciones de la presente obra en cualesquiera formas de impresión; sean electrónicas o mecánicas, presentes o futuras, sin el consentimiento previo y por escrito del autor. IMPRESO EN MEXICO PRINTED IN MEXICO LOS GUIÑOS DEL PASADO', '', file_b)

            file_b = re.sub(r'\n', '', file_b)
            file_b = file_b.lower()

            tt = file_b.split(' ')
            if len(tt)>=500:
                #print(tt)
    
    
     
            
                fdist = FreqDist(tt)
                most_frq_words = fdist.most_common(50)
                
                for word, num in most_frq_words:
                    list_words.append(word)
                #print('\n\n\n\n',i, list_words)
                


                
            if list_words:
                
                #print(list_words)
                
                for words in list_words:
                    if not words in list(stops):
                        words_in_stop.append(words)
                
                if len(words_in_stop)>22:
                    cont_neardot+=1
                    print('\n\n\n',i,'\n\n\n\n',words_in_stop)
    print(cont_neardot)
            
                #print('\n\n\n\n',i)
                #print(tt)
                #print(list_words)
                #print(cont_word)
                
    
                
print(find_spanish_books('./Libros_Wiki_Index_Content/*'))
print(find_spanish_books('./Libros_Wiki/*'))
# Out:
#  ./Libros_Wiki_Index_Content\Adivinas infantiles- 1.txt
#
#
#
#  ['==', 'tamaño', 'adivinas', 'infantiles:', '', '¿qué', 'alto', 'casa', 'dos', '*', '(desde', ')', 'fernán', 'caballero', 'nadie', 'pesa', 'muchas', 'pude', 'cosa', 'río', '¿tamaño', 'gasta', 'come', 'carne', 'pan', '¿cuál']
#
#
#
#  ./Libros_Wiki_Index_Content\Adivinas infantiles- 2.txt
#
#
#
#  ['==', 'dos', 'cuatro', 'alto', 'adivinas', 'infantiles:', '', 'siempre', 'campo', 'pies', 'capa', 'no.', 'verde', 'muchas', 'vestido', 'rey', 'hijo', 'puedo', 'madre', '*', '(desde', ')', 'fernán']
#
#
#
#  ./Libros_Wiki_Index_Content\Benibaire.txt
#
#
#
#  ['tres', 'casa', 'aceite.', 'benibaire', '-no', 'cantaritos', 'legua,', 'huir.', 'dijo:', '::huir,', '::que', 'vais?', 'hurtar', '-¿queréis', 'vaya?', '-ven.', 'anduvieron', 'asustaron', 'echaron', 'gallo', '', 'cabritas', 'benibaire,', 'voz', 'vieron', 'carnero']
#
#
#
#  ./Libros_Wiki_Index_Content\Cuervo (Clarín)- 10.txt
#
#
#
# ...
